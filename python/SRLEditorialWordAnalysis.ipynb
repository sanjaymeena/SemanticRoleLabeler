# %%
# Load libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import glob
from matplotlib import font_manager
fontP = font_manager.FontProperties()
fontP.set_family('SimHei')
fontP.set_size(14)

plt.style.use('ggplot')
# %matplotlib inline  

#Plot the data:
my_colors = 'rgbkymc'  #red, green, blue, black, etc.

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75
plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 10, 6
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.serif'] = "cm"
plt.rcParams['text.latex.preamble'] = "\\usepackage{subdepth}, \\usepackage{type1cm}"

# %%
# Concat json files to create single file and write to disk
read_files = glob.iglob("data/editorial/words/*.json", recursive=True)
output_list = []


for f in read_files:
    
    with open(f) as json_data:
        data1=json.load(json_data)
        data1=data1['words']    
        for i in data1:
            output_list.append(i)
    #json.dump(output_list, outfile)
    
obj={'words': output_list}

with open("merged_words_file.json",'w') as outfile:
    json.dump(obj,outfile,indent=4)

# %%
# Import data
data_path1="merged_file.json"
data_path2="merged_words_file.json"


# with open(data_path1) as json_data:
#     data1 = json.load(json_data)

with open(data_path2) as json_data:
    data2 = json.load(json_data)

#data1=data1['sentences']    
data2=data2['words']   

#df=pd.DataFrame(data1)
df_words=pd.DataFrame(data2)

# %% [markdown]
# # SRL Word Analysis

# %% [markdown]
# We will perform some data analysis on the SRL data. With iterations, We will continue to add more information which will be for analysis, organizing and improving SRL and other associated tasks.

# %% [markdown]
# ## SRL Data Sources

# %% [markdown]
# Here we will provide information on the SRL data.

# %%
df_words
# Out:
#                                     file  pos               sentence  \
# 0        editorial_srl_100000_105000.txt   JJ             私生粉为什么要追车？
# 1        editorial_srl_100000_105000.txt   NN             私生粉为什么要追车？
# 2        editorial_srl_100000_105000.txt   AD             私生粉为什么要追车？
# 3        editorial_srl_100000_105000.txt   VV             私生粉为什么要追车？
# 4        editorial_srl_100000_105000.txt   VV             私生粉为什么要追车？
# 5        editorial_srl_100000_105000.txt   NN             私生粉为什么要追车？
# 6        editorial_srl_100000_105000.txt   PU             私生粉为什么要追车？
# 7        editorial_srl_100000_105000.txt   NN             手机进水了怎么办呢？
# 8        editorial_srl_100000_105000.txt   VV             手机进水了怎么办呢？
# 9        editorial_srl_100000_105000.txt   AS             手机进水了怎么办呢？
# 10       editorial_srl_100000_105000.txt   NN             手机进水了怎么办呢？
# 11       editorial_srl_100000_105000.txt   SP             手机进水了怎么办呢？
# 12       editorial_srl_100000_105000.txt   PU             手机进水了怎么办呢？
# ...

# %%
print("total words in the dataset in the dataset" , " :", len(df_words))
# Out:
# total words in the dataset in the dataset  : 4670565

# %% [markdown]
# ## Plot of the POS distribution of a given word

# %%
word='蔡少芬'
df_word_subset=df_words[df_words['word']==word]

print("total instances of the word : " , word , " in the dataset" , " :", len(df_word_subset))
title='POS distribution for word : ' + word
print(title)
if (len(df_word_subset)> 0) :
    df_word_subset_pos=df_word_subset['pos']
    df_relations=df_word_subset_pos.value_counts().to_frame()
    f = plt.figure(figsize=(10, 10)) # Change the size as necessary
    #Plot the data:
    df_relations.plot.barh(ax=f.gca(),color=my_colors) # figure.gca means "get current axis"
# Out:
# total instances of the word :  蔡少芬  in the dataset  : 6
# POS distribution for word : 蔡少芬

# %% [markdown]
# # Table information for the given word

# %%
df_word_subset
# Out:
#                                     file pos                      sentence  \
# 7844     editorial_srl_100000_105000.txt  NN                 舍友生日我送什么礼物好啊？
# 9152     editorial_srl_100000_105000.txt  NN            如果创业成功了，要首先给妈妈买礼物。
# 13065    editorial_srl_100000_105000.txt  NN                 异性朋友生日送什么礼物呢？
# 15197    editorial_srl_100000_105000.txt  NN             我的闺蜜过生日了，送什么礼物好呢。
# 16089    editorial_srl_100000_105000.txt  NN              我该给我的队友准备什么礼物好呢。
# 18823    editorial_srl_100000_105000.txt  NN            今天超市搞活动，买满三百送小礼物呢。
# 22803    editorial_srl_100000_105000.txt  NN               房东过生日了，送什么礼物好呢。
# 33122    editorial_srl_100000_105000.txt  NN               可以把手机当做礼物送给别人吗？
# 35375    editorial_srl_100000_105000.txt  NN                房东旅游回来带给我很多礼物。
# 40431    editorial_srl_100000_105000.txt  NN            有些粉丝会送礼物给自己喜欢的明星呢！
# 48114    editorial_srl_100000_105000.txt  NN             我的队友过生日了，送什么礼物好呢。
# ...

# %% [markdown]
# ## Table information of given (Word,POS) Pair

# %%
word='巿'
pos ='SP'
df_word_subset1=df_words[(df_words['word']==word) & (df_words['pos']==pos) ]

print("total instances of the word : " , word , " in the dataset" , " :", len(df_word_subset1))
title='POS distribution for word : ' + word
print(title)


df_word_subset1
# Out:
# total instances of the word :  巿  in the dataset  : 1
# POS distribution for word : 巿
#                                     file pos sentence  sentence_id  src word
# 4142892  editorial_srl_515000_520000.txt  SP  你在哪个城巿？           63  srl    巿

# %%
pos='SP'
df_pos_subset=df_words[df_words['pos']==pos]
print(len(df_pos_subset))
df_pos_subset
# Out:
# 120958
#                                     file pos                        sentence  \
# 11       editorial_srl_100000_105000.txt  SP                      手机进水了怎么办呢？
# 23       editorial_srl_100000_105000.txt  SP             以前没条件才合租，现在反而舍不得走了！
# 171      editorial_srl_100000_105000.txt  SP                  每个城市的地铁卡都有不同呢。
# 244      editorial_srl_100000_105000.txt  SP             租房不光看房子，也要看看房东怎么样呢。
# 296      editorial_srl_100000_105000.txt  SP          两个女生在一起合租，天呐，东西多得放不下啦！
# 331      editorial_srl_100000_105000.txt  SP                    一些瓷器上也有中国画呢。
# 348      editorial_srl_100000_105000.txt  SP                        粉丝是追星族吗？
# 358      editorial_srl_100000_105000.txt  SP                  平和堂的超市平均都贵好多啊。
# 440      editorial_srl_100000_105000.txt  SP                       同事能成为闺蜜吗？
# 453      editorial_srl_100000_105000.txt  SP                 我每次去超市都要花好多的钱啊。
# 467      editorial_srl_100000_105000.txt  SP                    我们家乡的玉米大丰收啦！
# ...
