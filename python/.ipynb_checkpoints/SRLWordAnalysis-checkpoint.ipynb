# %%
# Load libraries
import pandas as pd
import json
import matplotlib.pyplot as plt

from matplotlib import font_manager
fontP = font_manager.FontProperties()
fontP.set_family('SimHei')
fontP.set_size(14)

plt.style.use('ggplot')
# %matplotlib inline  

#Plot the data:
my_colors = 'rgbkymc'  #red, green, blue, black, etc.

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75
plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 10, 6
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.serif'] = "cm"
plt.rcParams['text.latex.preamble'] = "\\usepackage{subdepth}, \\usepackage{type1cm}"

# %%
# Import data
data_path1="data/srl_test.json"
data_path2="data/ldc_corpus.json"
data_path3="data/word_info_srl.json"


with open(data_path1) as json_data:
    data1 = json.load(json_data)

with open(data_path3) as json_data:
    data2 = json.load(json_data)

data1=data1['sentences']    
data2=data2['words']   

df=pd.DataFrame(data1)
df_words=pd.DataFrame(data2)

# %% [markdown]
# # SRL Word Analysis

# %% [markdown]
# We will perform some data analysis on the SRL data. With iterations, We will continue to add more information which will be for analysis, organizing and improving SRL and other associated tasks.

# %% [markdown]
# ## SRL Data Sources

# %% [markdown]
# Here we will provide information on the SRL data.

# %%
df_words
# Out:
#                                             file  pos             sentence  \
# 0       intent_srl_1_300_complete-good_cases.txt   VV               传张帅哥图来
# 1       intent_srl_1_300_complete-good_cases.txt   NR               传张帅哥图来
# 2       intent_srl_1_300_complete-good_cases.txt   NN               传张帅哥图来
# 3       intent_srl_1_300_complete-good_cases.txt   LC               传张帅哥图来
# 4       intent_srl_1_300_complete-good_cases.txt   BA  把你的照片发给我，我把我的照片发给你。
# 5       intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给你。
# 6       intent_srl_1_300_complete-good_cases.txt  DEG  把你的照片发给我，我把我的照片发给你。
# 7       intent_srl_1_300_complete-good_cases.txt   NN  把你的照片发给我，我把我的照片发给你。
# 8       intent_srl_1_300_complete-good_cases.txt   VV  把你的照片发给我，我把我的照片发给你。
# 9       intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给你。
# 10      intent_srl_1_300_complete-good_cases.txt   PU  把你的照片发给我，我把我的照片发给你。
# 11      intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给你。
# 12      intent_srl_1_300_complete-good_cases.txt   BA  把你的照片发给我，我把我的照片发给你。
# 13      intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给你。
# 14      intent_srl_1_300_complete-good_cases.txt  DEG  把你的照片发给我，我把我的照片发给你。
# 15      intent_srl_1_300_complete-good_cases.txt   NN  把你的照片发给我，我把我的照片发给你。
# 16      intent_srl_1_300_complete-good_cases.txt   VV  把你的照片发给我，我把我的照片发给你。
# 17      intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给你。
# 18      intent_srl_1_300_complete-good_cases.txt   PU  把你的照片发给我，我把我的照片发给你。
# 19      intent_srl_1_300_complete-good_cases.txt   BA  把你的照片发给我，我把我的照片发给她。
# 20      intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给她。
# 21      intent_srl_1_300_complete-good_cases.txt  DEG  把你的照片发给我，我把我的照片发给她。
# 22      intent_srl_1_300_complete-good_cases.txt   NN  把你的照片发给我，我把我的照片发给她。
# 23      intent_srl_1_300_complete-good_cases.txt   VV  把你的照片发给我，我把我的照片发给她。
# 24      intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给她。
# 25      intent_srl_1_300_complete-good_cases.txt   PU  把你的照片发给我，我把我的照片发给她。
# 26      intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给她。
# 27      intent_srl_1_300_complete-good_cases.txt   BA  把你的照片发给我，我把我的照片发给她。
# 28      intent_srl_1_300_complete-good_cases.txt   PN  把你的照片发给我，我把我的照片发给她。
# 29      intent_srl_1_300_complete-good_cases.txt  DEG  把你的照片发给我，我把我的照片发给她。
# ...                                          ...  ...                  ...
# 118452    srl_9750_10000_complete-good_cases.txt   NN          可以去递交申请加薪啊。
# 118453    srl_9750_10000_complete-good_cases.txt   VV          可以去递交申请加薪啊。
# 118454    srl_9750_10000_complete-good_cases.txt   SP          可以去递交申请加薪啊。
# 118455    srl_9750_10000_complete-good_cases.txt   PU          可以去递交申请加薪啊。
# 118456    srl_9750_10000_complete-good_cases.txt   AD               很会理财哦！
# 118457    srl_9750_10000_complete-good_cases.txt   VV               很会理财哦！
# 118458    srl_9750_10000_complete-good_cases.txt   VV               很会理财哦！
# 118459    srl_9750_10000_complete-good_cases.txt   SP               很会理财哦！
# 118460    srl_9750_10000_complete-good_cases.txt   PU               很会理财哦！
# 118461    srl_9750_10000_complete-good_cases.txt   AD                很满意吧！
# 118462    srl_9750_10000_complete-good_cases.txt   VA                很满意吧！
# 118463    srl_9750_10000_complete-good_cases.txt   SP                很满意吧！
# 118464    srl_9750_10000_complete-good_cases.txt   PU                很满意吧！
# 118465    srl_9750_10000_complete-good_cases.txt   AD              不要乱花钱哦！
# 118466    srl_9750_10000_complete-good_cases.txt   NR              不要乱花钱哦！
# 118467    srl_9750_10000_complete-good_cases.txt   SP              不要乱花钱哦！
# 118468    srl_9750_10000_complete-good_cases.txt   PU              不要乱花钱哦！
# 118469    srl_9750_10000_complete-good_cases.txt   VC            是做什么工作的呀！
# 118470    srl_9750_10000_complete-good_cases.txt   VV            是做什么工作的呀！
# 118471    srl_9750_10000_complete-good_cases.txt   DT            是做什么工作的呀！
# 118472    srl_9750_10000_complete-good_cases.txt   NN            是做什么工作的呀！
# 118473    srl_9750_10000_complete-good_cases.txt  DEC            是做什么工作的呀！
# 118474    srl_9750_10000_complete-good_cases.txt   SP            是做什么工作的呀！
# 118475    srl_9750_10000_complete-good_cases.txt   PU            是做什么工作的呀！
# 118476    srl_9750_10000_complete-good_cases.txt   AD              都很羡慕他吧！
# 118477    srl_9750_10000_complete-good_cases.txt   AD              都很羡慕他吧！
# 118478    srl_9750_10000_complete-good_cases.txt   VV              都很羡慕他吧！
# 118479    srl_9750_10000_complete-good_cases.txt   PN              都很羡慕他吧！
# 118480    srl_9750_10000_complete-good_cases.txt   SP              都很羡慕他吧！
# 118481    srl_9750_10000_complete-good_cases.txt   PU              都很羡慕他吧！
#
#         sentence_id     src word
# 0                 1  intent    传
# 1                 1  intent  张帅哥
# 2                 1  intent    图
# 3                 1  intent    来
# 4                 2  intent    把
# 5                 2  intent    你
# 6                 2  intent    的
# 7                 2  intent   照片
# 8                 2  intent   发给
# 9                 2  intent    我
# 10                2  intent    ，
# 11                2  intent    我
# 12                2  intent    把
# 13                2  intent    我
# 14                2  intent    的
# 15                2  intent   照片
# 16                2  intent   发给
# 17                2  intent    你
# 18                2  intent    。
# 19                3  intent    把
# 20                3  intent    你
# 21                3  intent    的
# 22                3  intent   照片
# 23                3  intent   发给
# 24                3  intent    我
# 25                3  intent    ，
# 26                3  intent    我
# 27                3  intent    把
# 28                3  intent    我
# 29                3  intent    的
# ...             ...     ...  ...
# 118452        16261     srl   申请
# 118453        16261     srl   加薪
# 118454        16261     srl    啊
# 118455        16261     srl    。
# 118456        16262     srl    很
# 118457        16262     srl    会
# 118458        16262     srl   理财
# 118459        16262     srl    哦
# 118460        16262     srl    ！
# 118461        16263     srl    很
# 118462        16263     srl   满意
# 118463        16263     srl    吧
# 118464        16263     srl    ！
# 118465        16264     srl   不要
# 118466        16264     srl  乱花钱
# 118467        16264     srl    哦
# 118468        16264     srl    ！
# 118469        16265     srl    是
# 118470        16265     srl    做
# 118471        16265     srl   什么
# 118472        16265     srl   工作
# 118473        16265     srl    的
# 118474        16265     srl    呀
# 118475        16265     srl    ！
# 118476        16266     srl    都
# 118477        16266     srl    很
# 118478        16266     srl   羡慕
# 118479        16266     srl    他
# 118480        16266     srl    吧
# 118481        16266     srl    ！
#
# [118482 rows x 6 columns]

# %%
print("total words in the dataset in the dataset" , " :", len(df_words))
# Out:
# total words in the dataset in the dataset  : 118482

# %% [markdown]
# ## Plot of the POS distribution of a given word

# %%
word='的'
df_word_subset=df_words[df_words['word']==word]

print("total instances of the word : " , word , " in the dataset" , " :", len(df_word_subset))
title='POS distribution for word : ' + word
print(title)
if (len(df_word_subset)> 0) :
    df_word_subset_pos=df_word_subset['pos']
    df_relations=df_word_subset_pos.value_counts().to_frame()
    f = plt.figure(figsize=(10, 10)) # Change the size as necessary
    #Plot the data:
    df_relations.plot.barh(ax=f.gca(),color=my_colors) # figure.gca means "get current axis"
# Out:
# total instances of the word :  的  in the dataset  : 5587
# POS distribution for word : 的

# %% [markdown]
# # Table information for the given word

# %%
df_word_subset
# Out:
#                                             file  pos               sentence  \
# 6       intent_srl_1_300_complete-good_cases.txt  DEG    把你的照片发给我，我把我的照片发给你。
# 14      intent_srl_1_300_complete-good_cases.txt  DEG    把你的照片发给我，我把我的照片发给你。
# 21      intent_srl_1_300_complete-good_cases.txt  DEG    把你的照片发给我，我把我的照片发给她。
# 29      intent_srl_1_300_complete-good_cases.txt  DEG    把你的照片发给我，我把我的照片发给她。
# 36      intent_srl_1_300_complete-good_cases.txt  DEG    把你的照片发给我，我把我的照片发给他。
# 44      intent_srl_1_300_complete-good_cases.txt  DEG    把你的照片发给我，我把我的照片发给他。
# 51      intent_srl_1_300_complete-good_cases.txt  DEG    把他的照片发给我，我把我的照片发给他。
# 59      intent_srl_1_300_complete-good_cases.txt  DEG    把他的照片发给我，我把我的照片发给他。
# 474     intent_srl_1_300_complete-good_cases.txt  DEC              发大尺度的美女图。
# 480     intent_srl_1_300_complete-good_cases.txt  DEC             发点白雪的美图给我。
# 488     intent_srl_1_300_complete-good_cases.txt  DEC           发点超人的照片过来给我。
# 510     intent_srl_1_300_complete-good_cases.txt  DEC                发点搞笑的图片
# 515     intent_srl_1_300_complete-good_cases.txt  DEC               发点搞笑的图片。
# 521     intent_srl_1_300_complete-good_cases.txt  DEC          发点搞笑的图片来逗我开心。
# 539     intent_srl_1_300_complete-good_cases.txt  DEC             发点黄致列的图给我。
# 547     intent_srl_1_300_complete-good_cases.txt  DEC            发点肌肉男的图片给我。
# 563     intent_srl_1_300_complete-good_cases.txt  DEC             发点浪漫的图片给我。
# 585     intent_srl_1_300_complete-good_cases.txt  DEC             发点奶茶妹妹的美图。
# 591     intent_srl_1_300_complete-good_cases.txt  DEG            发点皮卡丘的萌图给我。
# 600     intent_srl_1_300_complete-good_cases.txt  DEC           发点清新淡雅的图片给我。
# 608     intent_srl_1_300_complete-good_cases.txt  DEC             发点清新的自然美图。
# 616     intent_srl_1_300_complete-good_cases.txt  DEC           发点清新自然的美图给我。
# 625     intent_srl_1_300_complete-good_cases.txt  DEG           发点秋天红叶的美图给我。
# 660     intent_srl_1_300_complete-good_cases.txt  DEC           发点唯美的动漫图片给我。
# 670     intent_srl_1_300_complete-good_cases.txt  DEC             发点污污的图片给我。
# 679     intent_srl_1_300_complete-good_cases.txt  DEG           发点性感美女的图片给我。
# 688     intent_srl_1_300_complete-good_cases.txt  DEC             发点有创意的图片来。
# 695     intent_srl_1_300_complete-good_cases.txt  DEC            发点张柏芝的美图给我。
# 703     intent_srl_1_300_complete-good_cases.txt  DEC             发点赵薇的美图给我。
# 711     intent_srl_1_300_complete-good_cases.txt  DEC          发点震撼人心的美景图给我。
# ...                                          ...  ...                    ...
# 117893    srl_9750_10000_complete-good_cases.txt  DEC         个月那么多的支出都来自工资。
# 117904    srl_9750_10000_complete-good_cases.txt  DEG      重要，一家人的生活全是工资在支持。
# 117922    srl_9750_10000_complete-good_cases.txt  DEC              干，会越来越好的。
# 117937    srl_9750_10000_complete-good_cases.txt  DEG           性质决定了一个人的工资。
# 117954    srl_9750_10000_complete-good_cases.txt  DEC            考虑换份工资高的工作。
# 117962    srl_9750_10000_complete-good_cases.txt  DEC      点，除了必须花的除外，尽量少花钱。
# 117994    srl_9750_10000_complete-good_cases.txt  DEG        这么长时间了，是自身的原因吗？
# 117999    srl_9750_10000_complete-good_cases.txt  DEC               求职的人会很多。
# 118013    srl_9750_10000_complete-good_cases.txt  DEC               高，是干嘛的呢？
# 118035    srl_9750_10000_complete-good_cases.txt  DEC             工作会有涨薪的机会。
# 118043    srl_9750_10000_complete-good_cases.txt  DEC            换一个薪资较高的工作。
# 118061    srl_9750_10000_complete-good_cases.txt  DEC             找一份薪资高的工作。
# 118067    srl_9750_10000_complete-good_cases.txt  DEC              工作发更多的薪水。
# 118096    srl_9750_10000_complete-good_cases.txt  DEC               发的时候就发了。
# 118107    srl_9750_10000_complete-good_cases.txt  DEC        个公司都会规定一定的时间发呢。
# 118210    srl_9750_10000_complete-good_cases.txt  DEC               ？你做的不好吗？
# 118222    srl_9750_10000_complete-good_cases.txt  DEC    来，只要努力会有回报的，工资也会涨的。
# 118228    srl_9750_10000_complete-good_cases.txt   SP    来，只要努力会有回报的，工资也会涨的。
# 118238    srl_9750_10000_complete-good_cases.txt  DEG  你踏实肯干，老板会看到你的努力给你涨薪的。
# 118244    srl_9750_10000_complete-good_cases.txt  DEC  你踏实肯干，老板会看到你的努力给你涨薪的。
# 118290    srl_9750_10000_complete-good_cases.txt  DEC              表现，会有回报的。
# 118310    srl_9750_10000_complete-good_cases.txt  DEC                着急，会发的。
# 118328    srl_9750_10000_complete-good_cases.txt  DEC         可以挣一些够自己买衣服的钱。
# 118340    srl_9750_10000_complete-good_cases.txt  DEC              灰心，慢慢会长的。
# 118357    srl_9750_10000_complete-good_cases.txt  DEC             知道一定会很感动的。
# 118381    srl_9750_10000_complete-good_cases.txt  DEC            真是个有孝心的好孩子。
# 118402    srl_9750_10000_complete-good_cases.txt  DEC         也可以往老板的位置上努力啊！
# 118435    srl_9750_10000_complete-good_cases.txt  DEC               是你努力的结果。
# 118447    srl_9750_10000_complete-good_cases.txt  DEC            努力，老板总会看到的。
# 118473    srl_9750_10000_complete-good_cases.txt  DEC              是做什么工作的呀！
#
#         sentence_id     src word
# 6                 2  intent    的
# 14                2  intent    的
# 21                3  intent    的
# 29                3  intent    的
# 36                4  intent    的
# 44                4  intent    的
# 51                5  intent    的
# 59                5  intent    的
# 474              67  intent    的
# 480              68  intent    的
# 488              69  intent    的
# 510              72  intent    的
# 515              73  intent    的
# 521              74  intent    的
# 539              76  intent    的
# 547              77  intent    的
# 563              79  intent    的
# 585              82  intent    的
# 591              83  intent    的
# 600              84  intent    的
# 608              85  intent    的
# 616              86  intent    的
# 625              87  intent    的
# 660              92  intent    的
# 670              93  intent    的
# 679              94  intent    的
# 688              95  intent    的
# 695              96  intent    的
# 703              97  intent    的
# 711              98  intent    的
# ...             ...     ...  ...
# 117893        16176     srl    的
# 117904        16177     srl    的
# 117922        16179     srl    的
# 117937        16181     srl    的
# 117954        16184     srl    的
# 117962        16185     srl    的
# 117994        16189     srl    的
# 117999        16190     srl    的
# 118013        16192     srl    的
# 118035        16196     srl    的
# 118043        16197     srl    的
# 118061        16200     srl    的
# 118067        16201     srl    的
# 118096        16207     srl    的
# 118107        16208     srl    的
# 118210        16224     srl    的
# 118222        16225     srl    的
# 118228        16225     srl    的
# 118238        16226     srl    的
# 118244        16226     srl    的
# 118290        16233     srl    的
# 118310        16237     srl    的
# 118328        16240     srl    的
# 118340        16242     srl    的
# 118357        16245     srl    的
# 118381        16250     srl    的
# 118402        16253     srl    的
# 118435        16258     srl    的
# 118447        16260     srl    的
# 118473        16265     srl    的
#
# [5587 rows x 6 columns]

# %% [markdown]
# ## Table information of given (Word,POS) Pair

# %%
word='的'
pos ='DEV'
df_word_subset1=df_words[(df_words['word']==word) & (df_words['pos']==pos) ]

print("total instances of the word : " , word , " in the dataset" , " :", len(df_word_subset1))
title='POS distribution for word : ' + word
print(title)


df_word_subset1
# Out:
# total instances of the word :  的  in the dataset  : 43
# POS distribution for word : 的
#                                                   file  pos  \
# 10803     intent_srl_3900_4200_complete-good_cases.txt  DEV
# 14684   memory_nickname_enhace_complete-good_cases.txt  DEV
# 24059              enhance_MOD_complete-good_cases.txt  DEV
# 24836              enhance_MOD_complete-good_cases.txt  DEV
# 25099              enhance_MOD_complete-good_cases.txt  DEV
# 25376              enhance_MOD_complete-good_cases.txt  DEV
# 25874              enhance_MOD_complete-good_cases.txt  DEV
# 26743              enhance_MOD_complete-good_cases.txt  DEV
# 34140               HIT_format_complete-good_cases.txt  DEV
# 39030          srl_10001_10300_complete-good_cases.txt  DEV
# 39092          srl_10001_10300_complete-good_cases.txt  DEV
# 43805          srl_10600_10900_complete-good_cases.txt  DEV
# 47790            srl_1250_1500_complete-good_cases.txt  DEV
# 50929          srl_13900_14200_complete-good_cases.txt  DEV
# 51074          srl_13900_14200_complete-good_cases.txt  DEV
# 51092          srl_13900_14200_complete-good_cases.txt  DEV
# 59604          srl_16600_16900_complete-good_cases.txt  DEV
# 61836            srl_1750_2000_complete-good_cases.txt  DEV
# 65188            srl_2000_2250_complete-good_cases.txt  DEV
# 65306            srl_2250_2500_complete-good_cases.txt  DEV
# 65350            srl_2250_2500_complete-good_cases.txt  DEV
# 67058            srl_2500_2750_complete-good_cases.txt  DEV
# 77380            srl_4000_4250_complete-good_cases.txt  DEV
# 82023            srl_5000_5250_complete-good_cases.txt  DEV
# 90557            srl_6000_6250_complete-good_cases.txt  DEV
# 90823            srl_6000_6250_complete-good_cases.txt  DEV
# 93110            srl_6250_6500_complete-good_cases.txt  DEV
# 93793            srl_6500_6750_complete-good_cases.txt  DEV
# 96658            srl_7000_7250_complete-good_cases.txt  DEV
# 96778            srl_7000_7250_complete-good_cases.txt  DEV
# 100688           srl_7500_7750_complete-good_cases.txt  DEV
# 103488           srl_7750_8000_complete-good_cases.txt  DEV
# 104547           srl_7750_8000_complete-good_cases.txt  DEV
# 109016           srl_8500_8750_complete-good_cases.txt  DEV
# 109022           srl_8500_8750_complete-good_cases.txt  DEV
# 110520           srl_8750_9000_complete-good_cases.txt  DEV
# 110548           srl_8750_9000_complete-good_cases.txt  DEV
# 110593           srl_8750_9000_complete-good_cases.txt  DEV
# 112101           srl_9000_9250_complete-good_cases.txt  DEV
# 114223           srl_9250_9500_complete-good_cases.txt  DEV
# 114992           srl_9250_9500_complete-good_cases.txt  DEV
# 115214           srl_9250_9500_complete-good_cases.txt  DEV
# 115700           srl_9500_9750_complete-good_cases.txt  DEV
#
#                            sentence  sentence_id     src word
# 10803               张天宝谁呀干什么的把他照片发来         1425  intent    的
# 14684                你还得叫我姐呢，何来小的说。         2004  memory    的
# 24059             努力的让自己变得更好,偶尔也会自卑         3381     srl    的
# 24836      她去医院吧。确切的说这是你奶奶想获得更多人的关心         3450     srl    的
# 25099        肚子还想优雅?呵呵。加油减掉就可以优雅的谈了         3473     srl    的
# 25376              清华北大的童鞋们,压力是相对的啦         3498     srl    的
# 25874    补习班,基本想考好大学的都要去报这玩意,还不便宜的说         3542     srl    的
# 26743   她回家,狠狠的亲她一口,然后沉痛的说,对不起我喜欢男人         3613     srl    的
# 34140                     说一个屋一点的笑话         4387     srl    的
# 39030                个假作业多的要死，不如不放。         5164     srl    的
# 39092                个假作业多的要死，不如不放。         5178     srl    的
# 43805      ，我还没看过这部。到时候就去找这个版本的看好了。         5741     srl    的
# 47790              喜欢性格开朗活泼的能玩的开的吧。         6229     srl    的
# 50929                  要勇敢的去追求我的爱情。         6649     srl    的
# 51074      也是这样想的，条件太好的不行，比自己差的不愿意。         6665     srl    的
# 51092   我觉得对于一些自己不能退让的要坚持，其他的可以放松些。         6666     srl    的
# 59604                才知道！我已经穷的喝西北风了         7793     srl    的
# 61836                  吧，你最好好心的拒绝她们         8128     srl    的
# 65188                         是故意的么         8616     srl    的
# 65306                   ，那你就去大胆的追她呀         8635     srl    的
# 65350          吧，别着急，这不已经有了个良好的开始了吗         8639     srl    的
# 67058            您比我好，我一碰到光就会晕晕的想睡觉         8918     srl    的
# 77380                     时间少的不够用啊！        10492     srl    的
# 82023              每个教舞蹈的老师身材都特别的棒！        11162     srl    的
# 90557                      宿舍的要去游泳。        12371     srl    的
# 90823                     与艺术是一体的吗？        12410     srl    的
# 93110                    很生气的走到办公室。        12732     srl    的
# 93793             说我走路一颠一颠的很搞笑，怎么改？        12830     srl    的
# 96658                   真是帅的让我无法呼吸。        13247     srl    的
# 96778                    乐器演奏的让人振奋。        13263     srl    的
# 100688                  种类不同的可以交配吗？        13834     srl    的
# 103488                   看起来是多么的宏伟。        14176     srl    的
# 104547                 的美术老师长的可漂亮呢！        14330     srl    的
# 109016            的爱情是需要你自己去努力的追求的。        14956     srl    的
# 109022         你认真的对待爱情，相信你会实现你的愿望。        14957     srl    的
# 110520                说不定正在悄悄的走向你哦！        15148     srl    的
# 110548             自己爱的爱自己的，总是很幸福的。        15152     srl    的
# 110593               是由两个人共同的信任来维持。        15156     srl    的
# 112101       个人只有拥有爱情才能让婚姻长久幸福的走下去。        15353     srl    的
# 114223                     是很好的爱好啊。        15635     srl    的
# 114992          了误会要及时的说开哦，说开就没事了呢。        15748     srl    的
# 115214              的友谊一定要好好的保持下去哦。        15780     srl    的
# 115700                 可以使人慢慢的独立起来。        15852     srl    的
